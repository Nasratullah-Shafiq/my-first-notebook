# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
dikw = pd.read_csv('/content/drive/MyDrive/Classroom/Advanced Data Analytics/Nasratullah Shafiq - DIKW_HW_Activity.csv')

# %%
dikw
# Out:
#   EmployeeID     EmployeeName   Department JoiningDate  Salary  Gender  \
# 0       E001     James Wilson        Sales  2022-01-15   50000    Male
# 1       E002     Maria Garcia  Engineering  2021-03-12   75000  Female
# 2       E003     Robert Brown           HR  2020-06-23   60000    Male
# 3       E004      Emily Davis  Engineering  2021-11-05   72000  Female
# 4       E005  Michael Johnson    Marketing  2022-05-20   65000    Male
#
#      Country  PerformanceScore  JobSatisfaction
# 0        USA                85                4
# 1         UK                92                5
# 2     Canada                88                4
# 3        USA                79                3
# 4  Australia                83                4

# %%
dikw.shape
# Out:
# (5, 9)

# %%
dikw.info
# Out:
# <bound method DataFrame.info of   EmployeeID     EmployeeName   Department JoiningDate  Salary  Gender  \
# 0       E001     James Wilson        Sales  2022-01-15   50000    Male
# 1       E002     Maria Garcia  Engineering  2021-03-12   75000  Female
# 2       E003     Robert Brown           HR  2020-06-23   60000    Male
# 3       E004      Emily Davis  Engineering  2021-11-05   72000  Female
# 4       E005  Michael Johnson    Marketing  2022-05-20   65000    Male
#
#      Country  PerformanceScore  JobSatisfaction
# 0        USA                85                4
# 1         UK                92                5
# 2     Canada                88                4
# 3        USA                79                3
# 4  Australia                83                4  >
